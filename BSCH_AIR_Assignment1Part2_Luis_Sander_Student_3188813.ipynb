# %% [markdown]
# # BSCH-AIR - Assignment 1 Part 2
#
# # Student Name: ______________ Student Number: _______________________
#
#
# | Course 	          | BSCH                  |
# |  -------------|-------------|
# | Stage / Year        | 4                     |
# | Module 	          | AIR                   |
# |Semester             |	2                     |
# |Assignment           |	Assignment 01 Part 2  |
# |Date of Title Issue  |	15th February, 2026      |
# |Assignment Deadline  |	See Moodle |
# |Assignment %         | 5%                   |
# |Assignment Submission| Upload to moodle      |
#
# <div style="text-align: right"> Authors: A Cronin, J Lebron </div>

# %%
# Run this cell first so you have the necessary imports for the rest of the cells

# imports
import numpy as np # allow access to the numpy library to create matrices
from datetime import datetime
current_time = datetime.now()
print("Libraries imported successfully. ",current_time)

# %% [markdown]
# # Assignment 1 Submission
# Assignment 1 consists of 3 parts:
# 1. Part 1 python notebook submitted via moodle
# 2. Part 2 python notebook submitted via moodle
# 3. Part 3 in-class tutorial
#
# Part 1 and Part 2, for each:
# Save into a single .zip file submitted via Moodle:
# - [x]  ipynb notebook with your code and explanations
# - [x]  CoverSheet saved as PDF
# - [x]  AI Declaration saved as PDF
#
# ##### This will make up the 2 take-home parts of assignment 1.
#
# - [ ]  Part 3 will consist of an in-class tutorial, details TBD.
#
# #### All 3 assignment parts together make up 20% of the module.
#
#
# # Tasks
# * Complete all questions using **Tips** provided below. All questions carry equal marks.
# * Rename this file with Student Name and Student Number
# * Include Student Name and Student Number at the top of this file.
# * Submit to moodle with cover sheet and AI declaration

# %% [markdown]
# # Part 1 - Probability Theory
#
# ## Q1. Probability
# You have built two quadrotors guarding your house. From earlier experiments with a single quadrotor, we observed that the probability mass function describing the presence of a quadrotor is P*(X) = (0.2,0.2,0.6)* where *X ∈ {house,street,backyard}*.<br>
# For this exercise, we assume the locations of both quadrotors are independent of each other.<br>
#
# What is the probability both quadrotors are in the backyard at the same time?
#
# Create separate variables of each of the component probabilities and print all calculations.

# %%
# solution

# %% [markdown]
# ## Q2. Conditional Probability
# Assume you have installed a sophisticated vision system on your quadrotor to recognize doors with a probability of 0.9, i.e., *P(door is detected | quadrotor is in front of door) = 0.9*. <br>
# However, navigating through a door only suceeds with a probability of 0.7, i.e., *P(door is traversed | door is detected) = 0.7*.<br>
#
# What is the probability of successfully detecting and traversing a door when the quadrotor is in front of a door?
#
# Create separate variables of each of the component probabilities and show all calculations.

# %%
# solution

# %% [markdown]
# ## Q3. Joint Probability
# Now let's further assume, that there is a single charging station in the backyard. To prevent bumping into each other, the quadrotors are communicating with each other to ensure that they are not flying in the same area. As a result, their locations are not independent of each other anymore. The resulting joint probability table now looks as follows:
#
# | P(X,Y) 	| X=House 	| X=Street 	| X=Backyard 	|
# |-----------|---------|----------|------------|
# | Y=House 	| 0.0 	    | 0.1 	    | 0.2 	        |
# | Y=Street 	| 0.1 	    | 0.0 	    | 0.2 	        |
# | Y=Backyard| 0.2 	    | 0.2 	    | 0.0 	        |
#
# What is the probability of (at least) one quadrotor being in the street?

# %%
# solution

# %% [markdown]
# ## Q4. Bayes Rule
# Imagine a quadrotor seeks its charging station which is marked with many bright lamps.<br>
# The quadrotor is equipped with a binary brightness sensor that can measure either bright or ¬bright.<br>
# The binary world state is either home or ¬home with the prior $P(home)=0.2$.<br>
#
# Moreover we know:<br>
# $P(bright|home)=0.8$<br>
# and<br>
# $P(bright|¬home)=0.3$<br>
#
# Assume the robot observes light, what is the probability $P(home|bright)$ that it is above the charging base?

# %%
# solution

# %% [markdown]
# # Part 2 - Statistics
#
# ## Q1.	Basic Statistics Operations
# Compute the sample mean, sample variance and standard deviation of the following time series:
#
# $-1.5,2,5,1.1,1,4,2,0,2,2,3,4.4,4.20,11,33,2.2,-0.09$
#
# Use the the numpy methods below:<br>
# - [Mean](https://numpy.org/doc/stable/reference/generated/numpy.mean.html)
# - [Variance](https://docs.scipy.org/doc/numpy/reference/generated/numpy.var.html)
# - [Standard deviation](https://docs.scipy.org/doc/numpy/reference/generated/numpy.std.html)
#
# Formulea are provided for reference only:<br>
# Sample Mean : $\mu(X)=\frac{1}{n}\sum_{i}^n x_i$<br>
# Variance: $\mathrm{Var}(X)=\frac{1}{n-1}\sum_{i}^n (x_i-\mu)^2$<br>
# Standard Deviation $\sigma(X)=\sqrt{\mathrm{Var}(X)}$

# %%
# solution

# %% [markdown]
# ## Q2. Statistics with Numpy
# In this exercise you are given the time series of a (stationary) quadrotor equipped with a GPS receiver. Calculate the statistics with numpy.<br>
# Note: you can use the numpy functions mean, var, cov. Use the two parameter version of cov, i.e., to compute the covariance of two vectors a and b use numpy.cov(a, b).

# %%
# solution - complete the missing code denoted by "TODO"
import numpy as np

# The following method ensures that the same set of random numbers are generated each time
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html
np.random.seed(0)
# The following method generates random number from a specified distribution
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.uniform.html
lat = np.random.uniform(low=0, high=60, size=(50,))
print("lat",lat)
lon = np.random.uniform(low=60, high=120, size=(50,))
print("lon",lon)
alt = np.random.uniform(low=120, high=180, size=(50,))
print("alt",alt)

def compute_means(lat,lon,alt):
   # TODO: implement mean computation (replace 'None' with correct value)
    mean_lat = None
    mean_lon = None
    mean_alt = None
    return (mean_lat,mean_lon,mean_alt)

def compute_vars(lat,lon,alt):
    # TODO: implement variance computation (replace 'None' with correct value)
    var_lat = None
    var_lon = None
    var_alt = None
    return (var_lat,var_lon,var_alt)

def compute_cov(lat,lon,alt):
    # TODO: implement covariance computation (replace 'None' with correct value)
    cov_lat_lon = None
    cov_lon_alt = None
    cov_lat_alt = None
    return (cov_lat_lon,cov_lon_alt,cov_lat_alt)

print("compute_means:\n", compute_means(lat, lon, alt))
print("compute_vars:\n", compute_vars(lat, lon, alt))
print("compute_cov:\n", compute_cov(lat, lon, alt))

####### Desired output ########
# lat [32.92881024 42.91136198 36.16580256 32.69299098 25.41928796 38.75364678
#  26.25523268 53.50638005 57.81976563 23.00649113 47.50350228 31.73369519
#  34.08267367 55.5357983   4.26216349  5.22775798  1.21310385 49.95719073
#  46.68940506 52.20072889 58.71710053 47.94951385 27.68876174 46.83175058
#   7.09646555 38.39526128  8.60119724 56.68013502 31.31089931 24.8797164
#  15.87333673 46.45402137 27.36901993 34.10603693  1.12738803 37.05812982
#  36.72574336 37.01603981 56.62488471 40.90921795 21.57047403 26.22191723
#  41.85787176  3.6135283  40.00600293 40.23827218 12.62295366  7.73557786
#  18.92570106 21.82264626]
# lon [ 94.21180623  86.31609081 119.30243028  66.12268864  72.53260537
#   69.67857107  99.18649953  75.19749615  87.97864637  74.66553552
#   69.53817502  66.62250847  99.37977537  68.29097708  71.7949417
#   82.12351024 109.25959379  65.82607655 110.27669445  65.76590447
#  118.5875679   88.1190721  118.60566529  96.29073118 104.35581476
#   62.35126754  76.96841775  67.21179367  77.76841185  67.12366314
#   79.07899076  84.85577967  63.84884978 101.54832716  93.99608725
#   75.92336946  91.39488321  65.63643065  94.55678973 115.75777185
#   79.11413715 100.0446228   67.90787174 102.97963225  77.36436558
#   70.99148172  95.19077609  61.20645277 109.73640175  60.28172857]
# alt [160.66899221 136.20047839 164.11164133 177.73131271 134.92518861
#  154.56944007 155.52251588 154.33511435 133.38489796 177.16494069
#  146.82752272 170.78452035 161.96875652 137.84621705 168.82786918
#  143.79034445 172.86619183 154.87637236 172.90412171 161.5518954
#  163.51525679 150.07946292 177.36501808 158.63941195 145.43130291
#  156.38359285 121.1515919  138.094489   159.61041225 137.40465643
#  157.08092574 145.72612206 128.12844385 137.89693956 154.19789464
#  155.45236567 154.45951493 159.19204919 159.1261962  145.88510613
#  173.79279575 142.0537122  146.15189552 173.5154013  168.37163934
#  162.23331501 126.01361324 175.16895682 162.85447797 179.93082039]
# compute_means:
#  (32.277907096532466, 84.45735364496964, 155.1153142873259)
# compute_vars:
#  (266.86324199257854, 301.00450113467093, 215.9667857176235)

# %% [markdown]
# ## Q3.	Accuracy of GPS
# The manufacturer of a high quality GPS receiver claims that his device achieves the following accuracies:
# * stddev per degree (latitude) = $5.1234567876°⋅10^{−06}$
# * stddev per degree (longitude) = $9.543454321°⋅10^{−06}$
#
#
# For Lake Titicaca,
# * 1° of latitude corresponds to 110656.29m (almost constant around the world) and
# * 1° of longitude corresponds to 107158.26m
#
# Source: http://www.csgnetwork.com/degreelenllavcalc.html
#
# What is the corresponding standard deviation of the GPS receiver in latitude in m in Lake Titicaca?
# What is the corresponding standard deviation of the GPS receiver in longitude in m in Lake Titicaca?
#
# ***
#
# **Tip:** [Typecast the scientific notation string to a float](https://python-reference.readthedocs.io/en/latest/docs/float/scientific.html)
#
# E.g. $12345678.9⋅10^{−05} = 12.3456789 \quad 1.234⋅10^{02} = 123.4$
# ```
# x = 1234567.8e-5
# y = 1.234e+2
# print(x)
# print(y)
# ```

# %%
# solution
